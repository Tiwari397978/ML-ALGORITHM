# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
np.random.seed(0)

# %%
iris=load_iris()
df=pd.DataFrame(iris.data, columns = iris.feature_names)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
df['species'] = pd.Categorical.from_codes(iris.target,iris.target_names)

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 5 columns]

# %%
df['is_train'] = np.random.uniform(0,1,len(df))<=0.75

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species  is_train
# 0       setosa      True
# 1       setosa      True
# 2       setosa      True
# 3       setosa      True
# 4       setosa      True
# ..         ...       ...
# 145  virginica      True
# 146  virginica      True
# 147  virginica     False
# 148  virginica      True
# 149  virginica     False
#
# [150 rows x 6 columns]

# %%
train,test = df[df['is_train'] == True], df[df['is_train'] == False]

# %%
print('the number of observation in the training:', len(train))
print('the number of observation in the test:', len(test))
# Out:
# the number of observation in the training: 118
# the number of observation in the test: 32

# %%
features = df.columns[:4]

# %%
features
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')

# %%
y = pd.factorize(train['species'][0])

# %%
y
# Out:
# (array([0, 0, 0, 0, 0, 0], dtype=int64), array(['setosa'], dtype=object))

# %%
clf = RandomForestClassifier(n_jobs=2 , random_state=0 )
clf.fit(train[features], y)

# %%
clf.predict(test[features])

# %%
clf.predict_proba(test[features])[0:10]

# %%
# Create actual english names for the plants for each predicted plant class
preds = iris.target_names[clf.predict(test[features])]

# %%
# View the PREDICTED species for the first five observations
preds[0:5]

# %%
# View the ACTUAL species for the first five observations
test['species'].head()
